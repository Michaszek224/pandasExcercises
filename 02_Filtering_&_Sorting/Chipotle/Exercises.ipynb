# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
chipo = pd.read_csv(url, sep="\t")
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo["item_price"] = chipo["item_price"].str.slice(1)
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN      2.39
# 1                                       [Clementine]      3.39
# 2                                            [Apple]      3.39
# 3                                                NaN      2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     16.98

# %%
chipo["item_price"].dtype
# Out:
# dtype('O')

# %%
chipo["item_price"] = chipo["item_price"].astype(float)

# %%
chipo.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
prices = chipo.groupby("item_name")["item_price"].max()
(prices > 10).sum()
# Out:
# np.int64(31)

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only three columns item_name choice_description and product_price

# %%
each_item = chipo.groupby(["item_name", "choice_description"])["item_price"].min()
each_item = each_item.reset_index()
each_item = each_item.rename({"item_price": "product_price"})
each_item
# Out:
#               item_name                                 choice_description  \
# 0     6 Pack Soft Drink                                             [Coke]
# 1     6 Pack Soft Drink                                        [Diet Coke]
# 2     6 Pack Soft Drink                                         [Lemonade]
# 3     6 Pack Soft Drink                                           [Nestea]
# 4     6 Pack Soft Drink                                           [Sprite]
# ...                 ...                                                ...
# 1854  Veggie Soft Tacos  [Fresh Tomato Salsa, [Black Beans, Cheese, Sou...
# 1855  Veggie Soft Tacos  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 1856  Veggie Soft Tacos  [Roasted Chili Corn Salsa (Medium), [Black Bea...
# 1857  Veggie Soft Tacos  [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# 1858  Veggie Soft Tacos  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
#
#       item_price
# 0           6.49
# 1           6.49
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
each_item = each_item.sort_values("item_name")
each_item
# Out:
#               item_name                                 choice_description  \
# 0     6 Pack Soft Drink                                             [Coke]
# 1     6 Pack Soft Drink                                        [Diet Coke]
# 2     6 Pack Soft Drink                                         [Lemonade]
# 3     6 Pack Soft Drink                                           [Nestea]
# 4     6 Pack Soft Drink                                           [Sprite]
# ...                 ...                                                ...
# 1857  Veggie Soft Tacos  [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# 1853  Veggie Soft Tacos  [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...
# 1852  Veggie Soft Tacos  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...
# 1854  Veggie Soft Tacos  [Fresh Tomato Salsa, [Black Beans, Cheese, Sou...
# 1858  Veggie Soft Tacos  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
#
#       item_price
# 0           6.49
# 1           6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
chipo.groupby("item_price")["quantity"].max().sort_values(ascending=False).head(1)
# Out:
# item_price
# 44.25    15
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo[chipo["item_name"]=="Veggie Salad Bowl"]["quantity"].sum()
# Out:
# np.int64(18)

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo[(chipo["item_name"]=="Canned Soda") & (chipo["quantity"] > 1)]["quantity"].count()
# Out:
# np.int64(20)
